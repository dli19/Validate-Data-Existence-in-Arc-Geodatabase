# %% [markdown]
# ## Data Records Check
#
# <h3> Author: Jim Li </h3>
# <h3>Date: 2021/10/07 </h3>
# <h3>Last Update: 2022/02/02 </h3>

# %%
## June 2021 report ##


import arcpy, os, xlrd

#assign existing GIS feature file path to variable "adp"
adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

report = 'June 2021.xls'

#assign newest monthly report excel file path to variable "fileL"
fileL = f"F:/Jim Li (jli)/Adam Monthly Planning Report/{report}"

#using open_workbook funtion from the xlrd library and assign the value to variable "wb"
wb = xlrd.open_workbook(fileL)

#using sheet_by_index function from the xlrd library and assign the value to variable "sheet"
#sheets in Microsoft Excel are starting with index 0
#the sheet to be processed is in sheet1 of the excel file
sheet = wb.sheet_by_index(1)

#Create three empty lists for later data stored
coLis = []
preLis = []
feaLis = []

#to index the attributes in Excel by rows (vertically), 
#starting with 1 because first row is field name
#cell_value function finds value in i row of 4th field from the left, in this case E field of Excel
#for each value that foud in each row of 4th field, append the value to empty list coLis[]
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

# print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 

#using an arcpy search cursor to find value in feature attribute table
#finding the addresses that are in the FullAddress field
#then append the value to empty list preLis[], (watch out for the data type!! in this step)
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
    for row in cursor:
        preLis.append(row)


#convert to a list data type, therefore append any value in preLis[] to feaLis[]
for a in preLis:
    feaLis.append(a[0])

    

#verify the number of features in Excel file and GIS address point dataset
print(f'The total number of address points in ADCOM_SSAP is',len(feaLis))
print(f'The total number of addresses for the respective month of the Excel sheet is',len(coLis))


#crosscheck between the Excel file and GIS address point dataset
check = all(item in coLis for item in feaLis)

#conditional verification
if check is True:
    print('Nothing new need to be updated!')
else:
    print('There are new addresses to be added, and they are listing below!!')


#print out any addresses that are not in the GIS address point dataset but in the Excel file
for item in coLis:
    if item not in feaLis:
        print(item)

#Conclude the operation is completed
print('Done!')
# Out:
# The total number of address points in ADCOM_SSAP is 228456
# The total number of addresses for the respective month of the Excel sheet is 87
# There are new addresses to be added, and they are listing below!!
# 14700 104TH AVE BLDG
# 14700 104TH AVE BLDG
# 14700 104TH AVE BLDG
# 14700 104TH AVE BLDG
# 14700 104TH AVE BLDG
# 14700 104TH AVE BLDG
# 10597 PARIS ST UNIT
# 10597 PARIS ST UNIT
# Done!

# %%
## July 2021 report ##



import arcpy, os, xlrd


adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/July 2021.xlsx"
wb = xlrd.open_workbook(fileL)
sheet = wb.sheet_by_index(1)
coLis = []
preLis = []
feaLis = []
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 
    
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
#     print(type(cursor))
    for row in cursor:
        preLis.append(row)
#     print(type(preLis[0][0]))
#     print(preLis)
for a in preLis:
    feaLis.append(a[0])
print(len(feaLis))
print(len(coLis))

check = all(item in coLis for item in feaLis)

if check is True:
    print('1')
else:
    print('2')

for item in coLis:
    if item not in feaLis:
        print(item)
        

print('Done!')
# Out:
# <class 'str'>
# 224955
# 70
# 2
# 10597 PARIS ST UNIT
# 10597 PARIS ST UNIT
# 10597 PARIS ST UNIT
# Done!

# %%
## August 2021 report ##



import arcpy, os, xlrd


adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/August 2021.xlsx"
wb = xlrd.open_workbook(fileL)
sheet = wb.sheet_by_index(1)
coLis = []
preLis = []
feaLis = []
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 
    
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
#     print(type(cursor))
    for row in cursor:
        preLis.append(row)
#     print(type(preLis[0][0]))
#     print(preLis)
for a in preLis:
    feaLis.append(a[0])
print(len(feaLis))
print(len(coLis))

check = all(item in coLis for item in feaLis)

if check is True:
    print('1')
else:
    print('2')

for item in coLis:
    if item not in feaLis:
        print(item)
        

print('Done!')
# Out:
# <class 'str'>
# 225471
# 79
# 2
# 10597 PARIS ST UNIT
# 5350 COLORADO BLVD
# 18011 E 89TH PL
# 17999 106TH AVE
# 18021 E 89TH PL
# 18031 E 89TH PL
# 18041 E 89TH PL
# Done!

# %%
## Sep 2021 report ##



import arcpy, os, xlrd


adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/Sep 2021.xlsx"
wb = xlrd.open_workbook(fileL)
sheet = wb.sheet_by_index(1)
coLis = []
preLis = []
feaLis = []
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 
    
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
#     print(type(cursor))
    for row in cursor:
        preLis.append(row)
#     print(type(preLis[0][0]))
#     print(preLis)
for a in preLis:
    feaLis.append(a[0])
print(len(feaLis))
print(len(coLis))

check = all(item in coLis for item in feaLis)

if check is True:
    print('1')
else:
    print('2')

for item in coLis:
    if item not in feaLis:
        print(item)

print('Done!')
# Out:
# <class 'str'>
# 225481
# 122
# 2
# 17969 106TH AVE
# 7190 COLORADO BLVD
# 16731 E 119TH AVE UNIT
# 16731 E 119TH AVE UNIT
# 16731 E 119TH AVE UNIT
# 16731 E 119TH AVE UNIT
# 16731 E 119TH AVE UNIT
# 16741 E 119TH AVE B
# 16741 E 119TH AVE D
# 16741 E 119TH AVE E
# 17979 106TH AVE
# 5821 QUEBEC ST
# 18101 E 89 TH PL
# 18111 E 89 TH PL
# 17990 106TH PL
# 18009 106TH AVE
# 11029 HAVANA ST
# 16611 E 119TH AVE UNIT
# 16611 E 119TH AVE UNIT
# 16611 E 119TH AVE UNIT
# 16611 E 119TH AVE UNIT
# 16741 E 119TH AVE A
# 16751 E 119TH AVE A
# 16751 E 119TH AVE B
# 16751 E 119TH AVE D
# 16751 E 119TH AVE C
# 16751 E 119TH AVE E
# 16761 E 119TH AVE D
# 16761 E 119TH AVE A
# 16761 E 119TH AVE C
# 16761 E 119TH AVE E
# 16871 E 119TH AVE B
# 16871 E 119TH AVE D
# 16871 E 119TH AVE A
# 16871 E 119TH AVE C
# 16871 E 119TH AVE E
# 16883 E 119TH AVE A
# 16883 E 119TH AVE C
# 16891 E 119TH AVE D
# 16897 E 119TH AVE E
# 16897 E 119TH AVE B
# 18081 E 89 TH PL
# Done!

# %%
## Oct 2021 report ##



import arcpy, os, xlrd


adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/Oct 2021.xlsx"
wb = xlrd.open_workbook(fileL)
sheet = wb.sheet_by_index(1)
coLis = []
preLis = []
feaLis = []
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 
    
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
#     print(type(cursor))
    for row in cursor:
        preLis.append(row)
#     print(type(preLis[0][0]))
#     print(preLis)
for a in preLis:
    feaLis.append(a[0])
print(len(feaLis))
print(len(coLis))

check = all(item in coLis for item in feaLis)

if check is True:
    print('1')
else:
    print('2')

for item in coLis:
    if item not in feaLis:
        print(item)

print('Done!')
# Out:
# <class 'str'>
# 225481
# 90
# 2
# Done!

# %%
## NOV 2021 report ##



import arcpy, os, xlrd


adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/Nov 2021.xlsx"
wb = xlrd.open_workbook(fileL)
sheet = wb.sheet_by_index(1)
coLis = []
preLis = []
feaLis = []
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 
    
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
#     print(type(cursor))
    for row in cursor:
        preLis.append(row)
#     print(type(preLis[0][0]))
#     print(preLis)
for a in preLis:
    feaLis.append(a[0])
print(len(feaLis))
print(len(coLis))

check = all(item in coLis for item in feaLis)

if check is True:
    print('1')
else:
    print('2')

for item in coLis:
    if item not in feaLis:
        print(item)

print('Done!')
# Out:
# <class 'str'>
# 225517
# 69
# 2
# 18141 E 89 TH
# 18191 E 89 TH
# Done!

# %%
## DEC 2021 report ##



import arcpy, os, xlrd


adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/Dec 2021.xlsx"
wb = xlrd.open_workbook(fileL)
sheet = wb.sheet_by_index(1)
coLis = []
preLis = []
feaLis = []
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 
    
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
#     print(type(cursor))
    for row in cursor:
        preLis.append(row)
#     print(type(preLis[0][0]))
#     print(preLis)
for a in preLis:
    feaLis.append(a[0])
print(f'The total numbers of address points in ADCOM_SSAP is',len(feaLis))
print(f'The total number of addresses for the respecitive month of the Excel sheet is',len(coLis))

check = all(item in coLis for item in feaLis)

if check is True:
    print('You are up to date with the addresses.')
else:
    print('There are new addresses.')

for item in coLis:
    if item not in feaLis:
        print(item)

print('Done!')
# Out:
# <class 'str'>
# The total numbers of address points in ADCOM_SSAP is 225536
# The total number of addresses for the respecitive month of the Excel sheet is 69
# There are new addresses.
# 8808 WALDEN ST
# 11935 E NORFOLK CT
# 18960 E 96TH PL
# 18940 E 96TH PL
# 7300 BRIGHTON BLVD
# 5030 E 64TH AVE
# 5090 E 64TH AVE
# Done!

# %%
## Jan 2022 report ##



import arcpy, os, xlrd


adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/Jan 2022.xlsx"
wb = xlrd.open_workbook(fileL)
sheet = wb.sheet_by_index(1)
coLis = []
preLis = []
feaLis = []
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 
    
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
#     print(type(cursor))
    for row in cursor:
        preLis.append(row)
#     print(type(preLis[0][0]))
#     print(preLis)
for a in preLis:
    feaLis.append(a[0])
print(f'The total numbers of address points in ADCOM_SSAP is',len(feaLis))
print(f'The total number of addresses for the respecitive month of the Excel sheet is',len(coLis))

check = all(item in coLis for item in feaLis)

if check is True:
    print('You are up to date with the addresses.')
else:
    print('There are new addresses.')

for item in coLis:
    if item not in feaLis:
        print(item)

print('Done!')
# Out:
# <class 'str'>
# The total numbers of address points in ADCOM_SSAP is 226257
# The total number of addresses for the respecitive month of the Excel sheet is 54
# There are new addresses.
# 10259 XANADAU ST
# Done!

# %%
## Feb 2022 report ##



import arcpy, os, xlrd


adp = "C:/GIS/Master_Working/Master_Working.gdb/ADCOM_SSAP_MERGED_SCHEMA"

fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/Feb 2022.xlsx"
wb = xlrd.open_workbook(fileL)
sheet = wb.sheet_by_index(1)
coLis = []
preLis = []
feaLis = []
for i in range(1,sheet.nrows):
    coLis.append(sheet.cell_value(i,4).upper())

print(type(coLis[0]))
# print(coLis)
# with open(fileL, 'r') as CORep: 
    
with arcpy.da.SearchCursor(adp, ['FullAddress']) as cursor:
#     print(type(cursor))
    for row in cursor:
        preLis.append(row)
#     print(type(preLis[0][0]))
#     print(preLis)
for a in preLis:
    feaLis.append(a[0])
print(f'The total numbers of address points in ADCOM_SSAP is',len(feaLis))
print(f'The total number of addresses for the respecitive month of the Excel sheet is',len(coLis))

check = all(item in coLis for item in feaLis)

if check is True:
    print('You are up to date with the addresses.')
else:
    print('There are new addresses.')

for item in coLis:
    if item not in feaLis:
        print(item)

print('Done!')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-4-df24bb523d81> in <module>
#       9
#      10 fileL = "F:/Jim Li (jli)/Adam Monthly Planning Report/Feb 2022.xlsx"
# ---> 11 wb = xlrd.open_workbook(fileL)
#      12 sheet = wb.sheet_by_index(1)
#      13 coLis = []
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     168     # files that xlrd can parse don't start with the expected signature.
#     169     if file_format and file_format != 'xls':
# --> 170         raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
#     171
#     172     bk = open_workbook_xls(
#
# XLRDError: Excel xlsx file; not supported
